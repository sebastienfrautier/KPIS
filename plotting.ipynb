# %%
import pickle
import matplotlib.pyplot as plt
import os

# %%
file_name = '2017-11-30T10:32:26.446697_episode_20'

# %%
absolute_weights_path = 'weights/'

# %%
with open(absolute_weights_path + file_name, 'rb') as handle:
    config = pickle.load(handle)

# %%
plt.plot(config['running_reward_list'])
plt.ylabel('running reward')
plt.show()
